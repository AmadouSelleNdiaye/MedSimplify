# %%
import pandas as pd

# %% [markdown]
# # Handling the dataset

# %%
splits = {'train': 'train.csv', 'validation': 'validation.csv', 'test': 'test.csv'}
df_train = pd.read_csv("hf://datasets/cbasu/Med-EASi/" + splits["train"])

df_test = pd.read_csv("hf://datasets/cbasu/Med-EASi/" + splits["test"])

df_validation = pd.read_csv("hf://datasets/cbasu/Med-EASi/" + splits["validation"])

# %%
df_train
# Out:
#                                                  Expert  \
# 0     75-90 % of the affected people have mild intel...
# 1     A bandlike tightness around the chest or abdom...
# 2     A disrupted ossicular chain may be repaired du...
# 3     A posterior subcapsular cataract disproportion...
# 4     Abdominal pain (usually starting in one quadra...
# ...                                                 ...
# 1392  It may be either conntected to Group A strepto...
# 1393  Although his condition was incurable, Merrick ...
# 1394  Grignard reagents are basic and react with alc...
# 1395  With a weight below 100 pounds (45 kg), Buckle...
# 1396  It is almost never passed on from affected par...
#
#                                                  Simple  \
# 0     People with syndromic intellectual disabilitie...
# 1     Within hours to a few days, tingling, numbness...
# 2     If the ossicles have been damaged, they may be...
# 3     With a cataract near the back of the lens (pos...
# ...

# %% [markdown]
# # Load the model T5-Small

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM,BitsAndBytesConfig

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small")

# %% [markdown]
# # Test model T5-Small

# %%
input_text = "Summarize the medical report: CT also is required to accurately assess skull base bony changes, which are less visible on MRI."
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# The MRI is a diagnostic tool used to identify the underlying bone.

# %% [markdown]
# # Load the model DistillBART

# %%
# Load model directly

tokenizer = AutoTokenizer.from_pretrained("zaib32/autotrain-finetuned_distillbart-3664997842")
model = AutoModelForSeq2SeqLM.from_pretrained("zaib32/autotrain-finetuned_distillbart-3664997842")

# %% [markdown]
# # Test model DistillBART

# %%
input_text = "Summarize the medical report: CT also is required to accurately assess skull base bony changes, which are less visible on MRI."
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# The medical report states that CT is required to accurately assess skull base bony changes, which are less visible on MRI. CT also is required for accurate assessment of skull base changes. These changes can be found in the patient's MRI and are often less visible than in MRI. The patient is receiving a CT scan to assess the extent of these changes.

# %% [markdown]
# # Load the model BART-base

# %%
# Load model directly

tokenizer = AutoTokenizer.from_pretrained("facebook/bart-base")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/bart-base")

# %% [markdown]
# # Test model BART-base

# %%
input_text = "Summarize the medical report: CT also is required to accurately assess skull base bony changes, which are less visible on MRI."
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# Summarize the medical report: CT also is required to accurately assess skull base bony

# %% [markdown]
# #   Load the model SciFive-base

# %%
# Load model directly

tokenizer = AutoTokenizer.from_pretrained("razent/SciFive-base-Pubmed")
model = AutoModelForSeq2SeqLM.from_pretrained("razent/SciFive-base-Pubmed")

# %% [markdown]
# # Test model SciFive-base

# %%
input_text = "Summarize the medical report: CT also is required to accurately assess skull base bony changes, which are less visible on MRI."
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# : MRI is the gold standard for skull base evaluation.:::

# %% [markdown]
# # Load the model BART-large-cnn : First Test of a larger model

# %%
# Load model directly

tokenizer = AutoTokenizer.from_pretrained("facebook/bart-large-cnn")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/bart-large-cnn")

# %% [markdown]
# # Test model BART-large-cnn

# %%
input_text = "Summarize the medical report: CT also is required to accurately assess skull base bony changes, which are less visible on MRI."
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# . CT also is required to accurately assess skull base bony changes, which are less visible on MRI. CT is also needed to assess skull Base Bony Changes, which can be difficult to see on an MRI. For confidential support call the Samaritans on 08457 90 90 90 or visit a local Samaritans branch, see www.samaritans.org for details.

# %% [markdown]
# # Load the model flan-t5-xxl

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-xxl")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-xxl")
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
input_text = "Summarize the medical report: CT also is required to accurately assess skull base bony changes, which are less visible on MRI."
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# A CT scan is required to accurately assess skull base bony changes, which are less visible on

# %% [markdown]
# # Load the model flan-alpaca-gpt4-xl

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("declare-lab/flan-alpaca-gpt4-xl")
model = AutoModelForSeq2SeqLM.from_pretrained("declare-lab/flan-alpaca-gpt4-xl")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
input_text = "Summarize the medical report: CT also is required to accurately assess skull base bony changes, which are less visible on MRI."
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# The medical report states that a CT scan is necessary to accurately assess skull base bony changes that
